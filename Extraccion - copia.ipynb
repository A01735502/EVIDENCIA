# %%
#instalar librerias 

# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: C:\Users\jaque\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: C:\Users\jaque\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: C:\Users\jaque\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...

# %%
#importamos liberias requeridas 

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#convertifr en dataframe 

df= pd.read_csv("NEWYORK.csv")
df
# Out:
#                  id                                       listing_url  \
# 0      2.539000e+03                 https://www.airbnb.com/rooms/2539
# 1      2.595000e+03                 https://www.airbnb.com/rooms/2595
# 2      5.136000e+03                 https://www.airbnb.com/rooms/5136
# 3      6.848000e+03                 https://www.airbnb.com/rooms/6848
# 4      6.872000e+03                 https://www.airbnb.com/rooms/6872
# ...             ...                                               ...
# 36317  1.444360e+18  https://www.airbnb.com/rooms/1444361816139266163
# 36318  1.444370e+18  https://www.airbnb.com/rooms/1444367137899199563
# 36319  1.444470e+18  https://www.airbnb.com/rooms/1444466789913170608
# 36320  1.444500e+18  https://www.airbnb.com/rooms/1444497972042807274
# 36321  1.444530e+18  https://www.airbnb.com/rooms/1444533606768940303
#
#           scrape_id last_scraped           source  \
# 0      2.025060e+13   17/06/2025      city scrape
# ...

# %%
#verificamos la info del dataframe 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36322 entries, 0 to 36321
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            36322 non-null  float64
#  1   listing_url                                   36322 non-null  object
#  2   scrape_id                                     36322 non-null  float64
#  3   last_scraped                                  36322 non-null  object
#  4   source                                        36322 non-null  object
#  5   name                                          36320 non-null  object
#  6   description                                   35374 non-null  object
#  7   neighborhood_overview                         19084 non-null  object
#  8   picture_url                                   36322 non-null  object
# ...

# %%
filtro_50 = df.iloc[:, [
15, 16, 17, 18, 13, 25, 26, 28, 30, 31,
32, 33, 34, 35, 36, 37, 38, 40, 41, 42, 43,
44, 45, 46, 47, 48, 51, 52, 53, 54, 56,
57, 58, 60, 61, 62, 65, 66, 67, 68, 69,
70, 71, 74, 75, 76, 77, 78, 39, 50, 73]]

# %%
filtro_50.info
# Out:
# <bound method DataFrame.info of        host_response_time host_response_rate host_acceptance_rate  \
# 0      within a few hours               100%                  80%
# 1      within a few hours                94%                  24%
# 2                     NaN                NaN                 100%
# 3          within an hour               100%                 100%
# 4            within a day                91%                  33%
# ...                   ...                ...                  ...
# 36317      within an hour               100%                  80%
# 36318                 NaN                NaN                  NaN
# 36319      within an hour                89%                  50%
# 36320      within an hour               100%                 100%
# 36321                 NaN                NaN                  NaN
#
#       host_is_superhost            host_location host_has_profile_pic  \
# 0                     f             New York, NY                    t
# ...

# %%
filtro_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36322 entries, 0 to 36321
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host_response_time                            21550 non-null  object
#  1   host_response_rate                            21550 non-null  object
#  2   host_acceptance_rate                          21720 non-null  object
#  3   host_is_superhost                             35830 non-null  object
#  4   host_location                                 28913 non-null  object
#  5   host_has_profile_pic                          36307 non-null  object
#  6   host_identity_verified                        36307 non-null  object
#  7   neighbourhood_cleansed                        36322 non-null  object
#  8   latitude                                      36322 non-null  float64
# ...

# %%
#Convertir archivo filtrado a CSV
filtro_50.to_csv("Newyorkfiltrado.csv")
